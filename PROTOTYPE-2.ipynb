# %%
def ha():
    import pandas as pd
    import numpy as np
    import matplotlib.pyplot as plt
    import seaborn as sns


   


    df=pd.read_csv('heart2.csv')#heart UCI
    df


   

    y=df['target']# target
    x=df.drop(['target'],axis=1)#feature


   


    x.shape


   


    y.shape


    


    type(x)


    


    type(y)


    


    df.describe()# exploring the data


    


    
    # In[10]:


    from sklearn.model_selection import train_test_split
    xtr,xts,ytr,yts=train_test_split(x,y,test_size=0.25,random_state=40)


    # In[11]:


    xtr.shape


    # In[12]:


    xts.shape


    # In[13]:


  # # Using Random Forest Classifier

    # In[18]:


    from sklearn.ensemble import RandomForestClassifier
    dec=RandomForestClassifier(n_estimators=100)#hyper parameter training
    dec.fit(xtr,ytr)
    #Evaluate the dec tree
    print("Accuracy:",dec.score(xts,yts))
    yp=dec.predict(xts)

    print("accuracy dec:",dec.score(xts,yts))

    # In[14]:


    


    # Confusion matrix & Classification Model
    from sklearn.metrics import confusion_matrix
    from sklearn.metrics import classification_report


    # In[16]:


    cm=confusion_matrix(yts,yp)# to check original outcome to our models prediction
    #print(cm)
    sns.heatmap(cm,annot=True)


    # In[20]:


    print(classification_report(yts,yp))
    
    y_pred=dec.predict(xts)# prediction of data fit/trained from data on x test set
    cm=confusion_matrix(yts,y_pred)#creating a confusion matrix of test set of y and predicted y set to s=check the values were true
    sns.heatmap(cm,annot=True)

# %%
ha()
# Out:
# Accuracy: 0.8421052631578947
# accuracy dec: 0.8421052631578947
#               precision    recall  f1-score   support
#
#            0       0.82      0.82      0.82        34
#            1       0.86      0.86      0.86        42
#
#     accuracy                           0.84        76
#    macro avg       0.84      0.84      0.84        76
# weighted avg       0.84      0.84      0.84        76

# %%
def cav():
    import numpy as np
    import pandas as pd
    import matplotlib.pyplot as plt
    import seaborn as sns


    # In[2]:


    df=pd.read_csv('cardio_train.csv')
    df


    # In[3]:


    df=df.drop(['id','age','gender','height'],axis=1)


    # In[4]:




    # In[5]:


    y=df['cardio']
    x=df.drop(['cardio'],axis=1)
    





    from sklearn.model_selection import train_test_split
    xtr,xts,ytr,yts=train_test_split(x,y,test_size=0.25,random_state=50)

    from sklearn.ensemble import RandomForestClassifier
    dec=RandomForestClassifier(n_estimators=100)#hyper parameter training
    dec.fit(xtr,ytr)
    #Evaluate the dec tree
    print("Accuracy :",dec.score(xts,yts))
    yp=dec.predict(xts)

    # Adding cross Validation
   # from sklearn.model_selection import cross_val_score
    #cv_score=cross_val_score(dec,x,y,cv=5)
    #print("accuracy :",np.mean(cv_score))

    # Confusion matrix & Classification Model
    from sklearn.metrics import confusion_matrix
    from sklearn.metrics import classification_report


    # In[27]:


    #confusion_matrix(yts,yp)


    # In[28]:


    
    #print(classification_report(yts,yp))


    # In[29]:


    y_pred=dec.predict(xts)# prediction of data fit/trained from data on x test set
    cm=confusion_matrix(yts,y_pred)#creating a confusion matrix of test set of y and predicted y set to s=check the values were true
    sns.heatmap(cm,annot=True)
    print(classification_report(yts,yp))

# %%
cav()
# Out:
# Accuracy : 0.7048
#               precision    recall  f1-score   support
#
#            0       0.68      0.77      0.73      8815
#            1       0.73      0.64      0.68      8685
#
#     accuracy                           0.70     17500
#    macro avg       0.71      0.70      0.70     17500
# weighted avg       0.71      0.70      0.70     17500

# %%
def can():
    import pandas as pd
    import numpy as np
    import matplotlib.pyplot as plt
    import seaborn as sns


    # In[2]:


    df=pd.read_csv('breast_cancer_data.csv')
    #df.drop([''],axis=1)
    df


    # In[3]:


    df=df.drop(['id','Unnamed: 32'],axis=1)


    # In[4]:


    df['diagnosis']=df['diagnosis'].map({'M':0,'B':1})# to replace the M, B to the 0,1
    df.diagnosis.unique()


    # In[5]:


    y=df['diagnosis']# target
    x=df.drop(['diagnosis'],axis=1)#feature


    # In[8]:


    x.shape


    # In[7]:


    y.shape


    # In[9]:


    type(x)


    # In[10]:


    type(y)


    # In[11]:


    df.describe()# exploring the data


    # In[12]:


    # Machine learning model
    from sklearn.model_selection import train_test_split
    xtr,xts,ytr,yts=train_test_split(x,y,test_size=0.25,stratify=y,random_state=50)


    # In[25]:


    xtr.shape


    # In[26]:


    xts.shape


   


    # In[29]:

    # #  Using Random Forest Classifier

    # In[32]:


    from sklearn.ensemble import RandomForestClassifier
    dec=RandomForestClassifier(n_estimators=50)#hyper parameter training
    dec.fit(xtr,ytr)
    #Evaluate the dec tree
    print("Accuracy :",dec.score(xts,yts))
    yp=dec.predict(xts)


    # In[33]:

    # Confusion matrix & Classification Model
    from sklearn.metrics import confusion_matrix
    from sklearn.metrics import classification_report


    # In[30]:



    cm=confusion_matrix(yts,yp)# to check original outcome to our models prediction
    print(cm)
    sns.heatmap(cm,annot=True)


    # In[31]:


    print(classification_report(yts,yp))

# %%
can()
# Out:
# Accuracy : 0.972027972027972
# [[51  2]
#  [ 2 88]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96        53
#            1       0.98      0.98      0.98        90
#
#     accuracy                           0.97       143
#    macro avg       0.97      0.97      0.97       143
# weighted avg       0.97      0.97      0.97       143

# %%
def dia():
    import pandas as pd
    import numpy as np
    import matplotlib.pyplot as plt
    import seaborn as sns


    # In[4]:


    df=pd.read_csv('diabetes.csv')
    df


    # In[7]:


    df.head()


    # In[8]:


    y=df['Outcome']# target value 
    x=df.drop(['Outcome'],axis=1)#feature
    x.shape
    y.shape


    # In[9]:


    type(x)


    # In[10]:


    type(y)


    # In[11]:


    x.fillna(df.median(),inplace=True)#all the nan values are removed
    x.isnull().sum()


    # In[12]:


    from sklearn.linear_model import LinearRegression
    lr=LinearRegression() #instanstiation
    lr.fit(x,y)#fitting / training the data


    # In[13]:


    from sklearn.model_selection import train_test_split
    xtr,xts,ytr,yts=train_test_split(x,y,test_size=0.25,random_state=10,stratify=y)


    # In[14]:


    xts.shape


    # In[15]:


    xtr.shape
    # # Using Random FOrest classifier
    from sklearn.ensemble import RandomForestClassifier
    dec=RandomForestClassifier(n_estimators=100)#hyper parameter training
    dec.fit(xtr,ytr)
    #Evaluate the dec tree
    print("Accuracy:",dec.score(xts,yts))
    yp=dec.predict(xts)
    
    from sklearn.metrics import confusion_matrix
    from sklearn.metrics import classification_report


    # In[30]:



    cm=confusion_matrix(yts,yp)# to check original outcome to our models prediction
    print(cm)
    sns.heatmap(cm,annot=True)


    # In[31]:


    print(classification_report(yts,yp))

# %%
dia()
# Out:
# Accuracy: 0.796875
# [[106  19]
#  [ 20  47]]
#               precision    recall  f1-score   support
#
#            0       0.84      0.85      0.84       125
#            1       0.71      0.70      0.71        67
#
#     accuracy                           0.80       192
#    macro avg       0.78      0.77      0.78       192
# weighted avg       0.80      0.80      0.80       192
