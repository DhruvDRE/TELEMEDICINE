# %%
pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-1.3.3-py3-none-win_amd64.whl (95.2 MB)
# Requirement already satisfied: scipy in c:\users\hp\appdata\roaming\python\python37\site-packages (from xgboost) (1.4.1)
# Requirement already satisfied: numpy in c:\users\hp\appdata\roaming\python\python37\site-packages (from xgboost) (1.18.4)
# Installing collected packages: xgboost
# Successfully installed xgboost-1.3.3
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.1; however, version 21.0.1 is available.
# You should consider upgrading via the 'C:\Users\hp\Anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
def ha():
    import pandas as pd
    import numpy as np
    import matplotlib.pyplot as plt
    import seaborn as sns


   


    df=pd.read_csv('heart2.csv')#heart UCI
    df


   

    y=df['target']# target
    x=df.drop(['target'],axis=1)#feature


   


    x.shape


   


    y.shape


    


    type(x)


    


    type(y)


    


    df.describe()# exploring the data


    


    
    # In[10]:


    from sklearn.model_selection import train_test_split
    xtr,xts,ytr,yts=train_test_split(x,y,test_size=0.25,random_state=45)


    # In[11]:


    xtr.shape


    # In[12]:


    xts.shape


    # In[13]:


 

    # In[18]:


    from xgboost import XGBClassifier
    model=XGBClassifier()
    model.fit(xtr,ytr)
    #Evaluate the dec tree
    print("Accuracy:",model.score(xts,yts))
    yp=model.predict(xts)

    print("accuracy dec:",model.score(xts,yts))

    # In[14]:


    


    # Confusion matrix & Classification Model
    from sklearn.metrics import confusion_matrix
    from sklearn.metrics import classification_report


    # In[16]:


    cm=confusion_matrix(yts,yp)# to check original outcome to our models prediction
    #print(cm)
    sns.heatmap(cm,annot=True)


    # In[20]:


    print(classification_report(yts,yp))
    
    y_pred=model.predict(xts)# prediction of data fit/trained from data on x test set
    cm=confusion_matrix(yts,y_pred)#creating a confusion matrix of test set of y and predicted y set to s=check the values were true
    sns.heatmap(cm,annot=True)

# %%
ha()
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [13:55:09] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Accuracy: 0.8552631578947368
# accuracy dec: 0.8552631578947368
#               precision    recall  f1-score   support
#
#            0       0.79      0.87      0.83        30
#            1       0.91      0.85      0.88        46
#
#     accuracy                           0.86        76
#    macro avg       0.85      0.86      0.85        76
# weighted avg       0.86      0.86      0.86        76

# %%
def cav():
    import numpy as np
    import pandas as pd
    import matplotlib.pyplot as plt
    import seaborn as sns


    # In[2]:


    df=pd.read_csv('cardio_train.csv')
    df


    # In[3]:


    df=df.drop(['id','age','gender','height'],axis=1)


    # In[4]:




    # In[5]:


    y=df['cardio']
    x=df.drop(['cardio'],axis=1)
    





    from sklearn.model_selection import train_test_split
    xtr,xts,ytr,yts=train_test_split(x,y,test_size=0.25,random_state=50)

  
    from xgboost import XGBClassifier
    model=XGBClassifier()
    model.fit(xtr,ytr)
    #Evaluate the dec tree
    print("Accuracy:",model.score(xts,yts))
    yp=model.predict(xts)

    print("accuracy dec:",model.score(xts,yts))

    # In[14]:


    


    # Confusion matrix & Classification Model
    from sklearn.metrics import confusion_matrix
    from sklearn.metrics import classification_report


    # In[16]:


    cm=confusion_matrix(yts,yp)# to check original outcome to our models prediction
    #print(cm)
    sns.heatmap(cm,annot=True)


    # In[20]:


    print(classification_report(yts,yp))
    
    y_pred=model.predict(xts)# prediction of data fit/trained from data on x test set
    cm=confusion_matrix(yts,y_pred)#creating a confusion matrix of test set of y and predicted y set to s=check the values were true
    sns.heatmap(cm,annot=True)

# %%
cav()
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [13:55:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Accuracy: 0.7310285714285715
# accuracy dec: 0.7310285714285715
#               precision    recall  f1-score   support
#
#            0       0.71      0.79      0.75      8815
#            1       0.76      0.67      0.71      8685
#
#     accuracy                           0.73     17500
#    macro avg       0.73      0.73      0.73     17500
# weighted avg       0.73      0.73      0.73     17500

# %%
def can():
    import pandas as pd
    import numpy as np
    import matplotlib.pyplot as plt
    import seaborn as sns


    # In[2]:


    df=pd.read_csv('breast_cancer_data.csv')
    #df.drop([''],axis=1)
    df


    # In[3]:


    df=df.drop(['id','Unnamed: 32'],axis=1)


    # In[4]:


    df['diagnosis']=df['diagnosis'].map({'M':0,'B':1})# to replace the M, B to the 0,1
    df.diagnosis.unique()


    # In[5]:


    y=df['diagnosis']# target
    x=df.drop(['diagnosis'],axis=1)#feature


    # In[8]:


    x.shape


    # In[7]:


    y.shape


    # In[9]:


    type(x)


    # In[10]:


    type(y)


    # In[11]:


    df.describe()# exploring the data


    # In[12]:


    # Machine learning model
    from sklearn.model_selection import train_test_split
    xtr,xts,ytr,yts=train_test_split(x,y,test_size=0.25,stratify=y,random_state=50)


    # In[25]:


    xtr.shape


    # In[26]:


    xts.shape


   


   
    from xgboost import XGBClassifier
    model=XGBClassifier()
    model.fit(xtr,ytr)
    #Evaluate the dec tree
    print("Accuracy:",model.score(xts,yts))
    yp=model.predict(xts)

    print("accuracy dec:",model.score(xts,yts))

    # In[14]:


    


    # Confusion matrix & Classification Model
    from sklearn.metrics import confusion_matrix
    from sklearn.metrics import classification_report


    # In[16]:


    cm=confusion_matrix(yts,yp)# to check original outcome to our models prediction
    #print(cm)
    sns.heatmap(cm,annot=True)


    # In[20]:


    print(classification_report(yts,yp))
    
    y_pred=model.predict(xts)# prediction of data fit/trained from data on x test set
    cm=confusion_matrix(yts,y_pred)#creating a confusion matrix of test set of y and predicted y set to s=check the values were true
    sns.heatmap(cm,annot=True)

# %%
can()
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [13:56:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Accuracy: 0.965034965034965
# accuracy dec: 0.965034965034965
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95        53
#            1       0.98      0.97      0.97        90
#
#     accuracy                           0.97       143
#    macro avg       0.96      0.96      0.96       143
# weighted avg       0.97      0.97      0.97       143

# %%
def dia():
    import pandas as pd
    import numpy as np
    import matplotlib.pyplot as plt
    import seaborn as sns


    # In[4]:


    df=pd.read_csv('diabetes.csv')
    df


    # In[7]:


    df.head()


    # In[8]:


    y=df['Outcome']# target value 
    x=df.drop(['Outcome'],axis=1)#feature
    x.shape
    y.shape


    # In[9]:


    type(x)


    # In[10]:


    type(y)


    # In[11]:


    x.fillna(df.median(),inplace=True)#all the nan values are removed
    x.isnull().sum()


    # In[12]:


    from sklearn.linear_model import LinearRegression
    lr=LinearRegression() #instanstiation
    lr.fit(x,y)#fitting / training the data


    # In[13]:


    from sklearn.model_selection import train_test_split
    xtr,xts,ytr,yts=train_test_split(x,y,test_size=0.25,random_state=10,stratify=y)


    # In[14]:


    xts.shape


    # In[15]:


    xtr.shape
   
    from xgboost import XGBClassifier
    model=XGBClassifier()
    model.fit(xtr,ytr)
    #Evaluate the dec tree
    print("Accuracy:",model.score(xts,yts))
    yp=model.predict(xts)

    print("accuracy dec:",model.score(xts,yts))

    # In[14]:


    


    # Confusion matrix & Classification Model
    from sklearn.metrics import confusion_matrix
    from sklearn.metrics import classification_report


    # In[16]:


    cm=confusion_matrix(yts,yp)# to check original outcome to our models prediction
    #print(cm)
    sns.heatmap(cm,annot=True)


    # In[20]:


    print(classification_report(yts,yp))
    
    y_pred=model.predict(xts)# prediction of data fit/trained from data on x test set
    cm=confusion_matrix(yts,y_pred)#creating a confusion matrix of test set of y and predicted y set to s=check the values were true
    sns.heatmap(cm,annot=True)

# %%
dia()
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [13:56:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Accuracy: 0.71875
# accuracy dec: 0.71875
#               precision    recall  f1-score   support
#
#            0       0.80      0.76      0.78       125
#            1       0.59      0.64      0.61        67
#
#     accuracy                           0.72       192
#    macro avg       0.69      0.70      0.70       192
# weighted avg       0.73      0.72      0.72       192
